# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

# %%
from src.features import (
    add_head_to_head_features,
    add_team_form_features,
    add_team_scoring_features,
    add_team_strategy_features,
    add_venue_features,
)
import pandas as pd

# %%
MATCH_DATASET_FILE = Path("../data/processed/match_by_match.csv")

# %%
match_df = pd.read_csv(MATCH_DATASET_FILE)
match_df
# Out:
#       match_id        date                                              venue  \
# 0      1082591  2017-04-05  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1      1082592  2017-04-06      Maharashtra Cricket Association Stadium, Pune
# 2      1082593  2017-04-07             Saurashtra Cricket Association Stadium
# 3      1082594  2017-04-08                             Holkar Cricket Stadium
# 4      1082595  2017-04-08                              M.Chinnaswamy Stadium
# ...        ...         ...                                                ...
# 1238    981011  2016-05-22   Shaheed Veer Narayan Singh International Stadium
# 1239    981013  2016-05-24                   M Chinnaswamy Stadium, Bengaluru
# 1240    981015  2016-05-25                        Arun Jaitley Stadium, Delhi
# 1241    981017  2016-05-27                        Arun Jaitley Stadium, Delhi
# 1242    981019  2016-05-29                   M Chinnaswamy Stadium, Bengaluru
#
#                             team1                        team2  \
# 0             Sunrisers Hyderabad  Royal Challengers Bengaluru
# 1                  Mumbai Indians      Rising Pune Supergiants
# 2                   Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiants                 Punjab Kings
# 4     Royal Challengers Bengaluru               Delhi Capitals
# ...                           ...                          ...
# 1238               Delhi Capitals  Royal Challengers Bengaluru
# 1239                Gujarat Lions  Royal Challengers Bengaluru
# 1240          Sunrisers Hyderabad        Kolkata Knight Riders
# 1241                Gujarat Lions          Sunrisers Hyderabad
# 1242          Sunrisers Hyderabad  Royal Challengers Bengaluru
#
#                       toss_winner toss_decision                       winner  \
# 0     Royal Challengers Bengaluru         field          Sunrisers Hyderabad
# 1         Rising Pune Supergiants         field      Rising Pune Supergiants
# 2           Kolkata Knight Riders         field        Kolkata Knight Riders
# 3                    Punjab Kings         field                 Punjab Kings
# 4     Royal Challengers Bengaluru           bat  Royal Challengers Bengaluru
# ...                           ...           ...                          ...
# 1238  Royal Challengers Bengaluru         field  Royal Challengers Bengaluru
# 1239  Royal Challengers Bengaluru         field  Royal Challengers Bengaluru
# 1240        Kolkata Knight Riders         field          Sunrisers Hyderabad
# 1241          Sunrisers Hyderabad         field          Sunrisers Hyderabad
# 1242          Sunrisers Hyderabad           bat          Sunrisers Hyderabad
#
#                  result  team1_score  team2_score  \
# 0        won by 35 runs          207          172
# 1      won by 7 wickets          184          187
# 2     won by 10 wickets          183          184
# 3      won by 6 wickets          163          164
# 4        won by 15 runs          157          142
# ...                 ...          ...          ...
# 1238   won by 6 wickets          138          139
# 1239   won by 4 wickets          158          159
# 1240     won by 22 runs          162          140
# 1241   won by 4 wickets          162          163
# 1242      won by 8 runs          208          200
#
#                                           team1_players  \
# 0     DA Warner, S Dhawan, MC Henriques, Yuvraj Sing...
# 1     AM Rahane, MA Agarwal, SPD Smith, BA Stokes, M...
# 2     JJ Roy, BB McCullum, SK Raina, AJ Finch, KD Ka...
# 3     HM Amla, M Vohra, WP Saha, AR Patel, GJ Maxwel...
# 4     CH Gayle, SR Watson, Mandeep Singh, KM Jadhav,...
# ...                                                 ...
# 1238  Q de Kock, RR Pant, KK Nair, SV Samson, SW Bil...
# 1239  AJ Finch, BB McCullum, SK Raina, KD Karthik, D...
# 1240  DA Warner, S Dhawan, MC Henriques, Yuvraj Sing...
# 1241  ER Dwivedi, BB McCullum, SK Raina, KD Karthik,...
# 1242  CH Gayle, V Kohli, AB de Villiers, KL Rahul, S...
#
#                                           team2_players
# 0     CH Gayle, Mandeep Singh, TM Head, KM Jadhav, S...
# 1     PA Patel, JC Buttler, RG Sharma, N Rana, AT Ra...
# 2     G Gambhir, CA Lynn, RV Uthappa, MK Pandey, YK ...
# 3     AM Rahane, MA Agarwal, SPD Smith, BA Stokes, M...
# 4     AP Tare, SW Billings, KK Nair, SV Samson, RR P...
# ...                                                 ...
# 1238  CH Gayle, V Kohli, AB de Villiers, KL Rahul, S...
# 1239  CH Gayle, V Kohli, AB de Villiers, KL Rahul, S...
# 1240  RV Uthappa, G Gambhir, C Munro, MK Pandey, YK ...
# 1241  DA Warner, S Dhawan, MC Henriques, Yuvraj Sing...
# 1242  DA Warner, S Dhawan, MC Henriques, Yuvraj Sing...
#
# [1243 rows x 13 columns]

# %%
match_df.shape
# Out:
# (1243, 13)

# %%
match_df.columns
# Out:
# Index(['match_id', 'date', 'venue', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'winner', 'result', 'team1_score', 'team2_score',
#        'team1_players', 'team2_players'],
#       dtype='str')

# %%
match_df = add_head_to_head_features(match_df)
match_df = add_team_form_features(match_df)
match_df = add_team_scoring_features(match_df)
match_df = add_team_strategy_features(match_df)
match_df = add_venue_features(match_df)
# Out:
# Added head_to_head_features:
#  - team1_total_wins_against_team2
#  - team2_total_wins_against_team1
#  - team1_wins_against_team2_last_three
#  - team2_wins_against_team1_last_three
# Added team_form_features:
#  - team1_form_last_5
#  - team2_form_last_5
# Added team_scoring_features:
#  - team1_last_5_avg_score
#  - team1_last_5_runs_conceded
#  - team2_last_5_avg_score
#  - team2_last_5_runs_conceded
# Added team_strategy_features:
#  - team1_chasing_win_rate
#  - team1_defending_win_rate
#  - team2_chasing_win_rate
#  - team2_defending_win_rate
# Added venue_features:
#  - venue_avg_score
#  - chasing_win_rate_venue
#  - team1_win_rate_at_venue
#  - team2_win_rate_at_venue

# %%
match_df.shape
# Out:
# (1243, 31)

# %%
match_df.columns
# Out:
# Index(['match_id', 'date', 'venue', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'winner', 'result', 'team1_score', 'team2_score',
#        'team1_players', 'team2_players', 'team1_total_wins_against_team2',
#        'team2_total_wins_against_team1', 'team1_wins_against_team2_last_three',
#        'team2_wins_against_team1_last_three', 'team1_form_last_5',
#        'team2_form_last_5', 'team1_last_5_avg_score',
#        'team1_last_5_runs_conceded', 'team2_last_5_avg_score',
#        'team2_last_5_runs_conceded', 'team1_chasing_win_rate',
#        'team1_defending_win_rate', 'team2_chasing_win_rate',
#        'team2_defending_win_rate', 'venue_avg_score', 'chasing_win_rate_venue',
#        'team1_win_rate_at_venue', 'team2_win_rate_at_venue'],
#       dtype='str')

# %%
OUTPUT_FOLDER = Path("../data/final")
OUTPUT_CSV_PATH = OUTPUT_FOLDER / "match_by_match.csv"

match_df.to_csv(OUTPUT_CSV_PATH, index=False)
print(f"Training Ready Dataset is saved at {OUTPUT_CSV_PATH}")
# Out:
# Training Ready Dataset is saved at ..\data\model_ready\match_by_match.csv
